# %%
console.log('test')

# %% [markdown]
# # test

# %%
console.log('test')
# Out:
# testing

# %%
console.log('test')

# %%
console.log('test')
# Out:
# <p>test</p>

# %%
console.log('test')

# %%
console.log('test')
# Out:
# testing

# %%
console.log('test')
# Out:
# testing
